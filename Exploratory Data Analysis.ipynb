# %% [markdown]
# ** **
# # Load Package
# ** **

# %%
import numpy as np 
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ** **
# # Load Data
# ** **

# %%
data = pd.read_csv('/content/drive/MyDrive/Research/Dataset/Dataset.csv')
data.head()
# Out:
#    No. Company Name                   Country    Industry Published Year  \
# 0    1   Sony Group                25-09-2018         NaN     26-09-2018
# 1    2      Samsung                       NaN         NaN            NaN
# 2    4    Accenture                   Ireland  Consulting     30-03-2021
# 3    5         Acer                    Taiwan         NaN            NaN
# 4    6        Adobe  United States of America         NaN            NaN
#
#   Last Revised                                               Link  \
# 0   01-04-2021  https://www.sony.com/en/SonyInfo/csr_report/hu...
# 1          NaN  https://www.samsungsds.com/en/digital_responsi...
# 2   31-03-2021  https://www.accenture.com/content/dam/accentur...
# 3          NaN                                                NaN
# 4          NaN  https://www.adobe.com/content/dam/cc/en/ai-eth...
#
#                                 Document Name  \
# 0             Sony Group AI Ethics Guidelines
# 1                        AI Ethics Principles
# 2  Responsible AI From principles to practice
# 3                                         NaN
# 4             Adobe’s Commitment to AI Ethics
#
#                                            Main Text  \
# 0  AI Engagement within Sony Group\nThrough the u...
# 1  AI Ethics Principles\nAI is a rapidly developi...
# 2  Responsible AI\nFrom principles to practice\nC...
# 3                                                NaN
# 4  Adobe’s Commitment to AI Ethics\nAt Adobe, our...
#
#                                              Comment
# 0                                                NaN
# 1                                                NaN
# 2  Addtional Details: https://www.accenture.com/u...
# 3                                                NaN
# 4  Addtional Details: https://www.adobe.com/conte...

# %%
text_data = data.drop(columns=['No.','Country', 'Industry', 'Published Year', 'Last Revised', 'Link', 'Comment'], axis=1)
text_data.head()
# Out:
#   Company Name                               Document Name  \
# 0   Sony Group             Sony Group AI Ethics Guidelines
# 1      Samsung                        AI Ethics Principles
# 2    Accenture  Responsible AI From principles to practice
# 3         Acer                                         NaN
# 4        Adobe             Adobe’s Commitment to AI Ethics
#
#                                            Main Text
# 0  AI Engagement within Sony Group\nThrough the u...
# 1  AI Ethics Principles\nAI is a rapidly developi...
# 2  Responsible AI\nFrom principles to practice\nC...
# 3                                                NaN
# 4  Adobe’s Commitment to AI Ethics\nAt Adobe, our...

# %%
#Exclude firms without AI Ethics or Responsible AI Guideline Document
text_data = text_data.dropna()
text_data
# Out:
#   Company Name                               Document Name  \
# 0   Sony Group             Sony Group AI Ethics Guidelines
# 1      Samsung                        AI Ethics Principles
# 2    Accenture  Responsible AI From principles to practice
# 4        Adobe             Adobe’s Commitment to AI Ethics
# 8     Alphabet                    Responsible AI practices
#
#                                            Main Text
# 0  AI Engagement within Sony Group\nThrough the u...
# 1  AI Ethics Principles\nAI is a rapidly developi...
# 2  Responsible AI\nFrom principles to practice\nC...
# 4  Adobe’s Commitment to AI Ethics\nAt Adobe, our...
# 8  Responsible AI practices\nThe development of A...

# %% [markdown]
# ** **
# #Step 2: Data Cleaning
# ** **
#
# Since the goal of this analysis is to perform topic modeling, we will solely focus on the text data from each paper, and drop other metadata columns

# %% [markdown]
# ## Remove punctuation/lower casing
#
# Next, let’s perform a simple preprocessing on the content of paper_text column to make them more amenable for analysis, and reliable results. To do that, we’ll use a regular expression to remove any punctuation, and then lowercase the text

# %%
# Load the regular expression library 
import re

# Remove punctuation
text_data['main_text_processed'] = text_data['Main Text'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the text to lowercase
text_data['main_text_processed'] = text_data['main_text_processed'].map(lambda x: x.lower())

# Print out the first rows of papers
text_data['main_text_processed'].head()
# Out:
# 0    ai engagement within sony group\nthrough the u...
# 1    ai ethics principles\nai is a rapidly developi...
# 2    responsible ai\nfrom principles to practice\nc...
# 4    adobe’s commitment to ai ethics\nat adobe our ...
# 8    responsible ai practices\nthe development of a...
# Name: main_text_processed, dtype: object

# %% [markdown]
# ## Tokenize words and further clean-up text
#
# Let’s tokenize each sentence into a list of words, removing punctuations and unnecessary characters altogether.

# %%
text_data.head()
# Out:
#   Company Name                               Document Name  \
# 0   Sony Group             Sony Group AI Ethics Guidelines
# 1      Samsung                        AI Ethics Principles
# 2    Accenture  Responsible AI From principles to practice
# 4        Adobe             Adobe’s Commitment to AI Ethics
# 8     Alphabet                    Responsible AI practices
#
#                                            Main Text  \
# 0  AI Engagement within Sony Group\nThrough the u...
# 1  AI Ethics Principles\nAI is a rapidly developi...
# 2  Responsible AI\nFrom principles to practice\nC...
# 4  Adobe’s Commitment to AI Ethics\nAt Adobe, our...
# 8  Responsible AI practices\nThe development of A...
#
#                                  main_text_processed
# 0  ai engagement within sony group\nthrough the u...
# 1  ai ethics principles\nai is a rapidly developi...
# 2  responsible ai\nfrom principles to practice\nc...
# 4  adobe’s commitment to ai ethics\nat adobe our ...
# 8  responsible ai practices\nthe development of a...

# %%
import gensim
from gensim.utils import simple_preprocess

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data = text_data.main_text_processed.values.tolist()
data_words = list(sent_to_words(data))

print(data_words[:1][0][:30])
# Out:
# ['ai', 'engagement', 'within', 'sony', 'group', 'through', 'the', 'utilization', 'of', 'artificial', 'intelligence', 'ai', 'sony', 'aims', 'to', 'contribute', 'to', 'the', 'development', 'of', 'peaceful', 'and', 'sustainable', 'society', 'while', 'delivering', 'kando', 'sense', 'of', 'excitement']
